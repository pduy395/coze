# %%
from llama_cpp import Llama
import llama_cpp
from langchain_community.llms import LlamaCpp

# %%
llm = Llama (model_path='C://Users//llm_intern//.cache//huggingface//hub//models--lmstudio-ai--gemma-2b-it-GGUF//snapshots//a0b140bfb922a743f89dd0682a24a17516071ab9//gemma-2b-it-q4_k_m.gguf',             
             n_ctx=8096,
             n_gpu_layers=18,
             main_gpu=0,             
)
# Out:
# llama_model_loader: loaded meta data with 21 key-value pairs and 164 tensors from C://Users//llm_intern//.cache//huggingface//hub//models--lmstudio-ai--gemma-2b-it-GGUF//snapshots//a0b140bfb922a743f89dd0682a24a17516071ab9//gemma-2b-it-q4_k_m.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma
# llama_model_loader: - kv   1:                               general.name str              = gemma-2b-it
# llama_model_loader: - kv   2:                       gemma.context_length u32              = 8192
# llama_model_loader: - kv   3:                          gemma.block_count u32              = 18
# llama_model_loader: - kv   4:                     gemma.embedding_length u32              = 2048
# llama_model_loader: - kv   5:                  gemma.feed_forward_length u32              = 16384
# ...

# %%
# !nvidia-smi
# Out:
# Tue Aug 27 12:37:09 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 522.06       Driver Version: 522.06       CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  Off |
# |  0%   52C    P8    20W / 450W |   3059MiB / 24564MiB |      6%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
res = llm.create_chat_completion(
		messages = [
			{
				"role": "user",
				"content": "write a poem 1000 words abou AI"
			}
		],
)
print(res)
# Out:
# Llama.generate: 21 prefix-match hit, remaining 1 prompt tokens to eval
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 res = llm.create_chat_completion(
#       2 		messages = [
#       3 			{
#       4 				"role": "user",
#       5 				"content": "write a poem 1000 words abou AI"
#       6 			}
#       7 		],
#       8 )
#       9 print(res)
#
# File d:\intern-llm\.venv\lib\site-packages\llama_cpp\llama.py:1898, in Llama.create_chat_completion(self, messages, functions, function_call, tools, tool_choice, temperature, top_p, top_k, min_p, typical_p, stream, stop, seed, response_format, max_tokens, presence_penalty, frequency_penalty, repeat_penalty, tfs_z, mirostat_mode, mirostat_tau, mirostat_eta, model, logits_processor, grammar, logit_bias, logprobs, top_logprobs)
#    1860 """Generate a chat completion from a list of messages.
#    1861
# ...

# %%
from langchain_community.llms import LlamaCpp

llm =  LlamaCpp(model_path='C://Users//llm_intern//.cache//huggingface//hub//models--lmstudio-ai--gemma-2b-it-GGUF//snapshots//a0b140bfb922a743f89dd0682a24a17516071ab9//gemma-2b-it-q4_k_m.gguf',
                n_gpu=-1)
# Out:
# llama_model_loader: loaded meta data with 21 key-value pairs and 164 tensors from C://Users//llm_intern//.cache//huggingface//hub//models--lmstudio-ai--gemma-2b-it-GGUF//snapshots//a0b140bfb922a743f89dd0682a24a17516071ab9//gemma-2b-it-q4_k_m.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma
# llama_model_loader: - kv   1:                               general.name str              = gemma-2b-it
# llama_model_loader: - kv   2:                       gemma.context_length u32              = 8192
# llama_model_loader: - kv   3:                          gemma.block_count u32              = 18
# llama_model_loader: - kv   4:                     gemma.embedding_length u32              = 2048
# llama_model_loader: - kv   5:                  gemma.feed_forward_length u32              = 16384
# ...
